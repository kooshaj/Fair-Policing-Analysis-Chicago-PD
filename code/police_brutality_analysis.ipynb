# %%
import pandas as pd

# %%
pd.read_csv("data/context_data/district_demographics/Districts.csv")
# Out:
#     District_No   District_Name Population   Latino    White   Black  \
# 0             1         Central     62,781    3,766   32,952  13,452
# 1             2       Wentworth     95,439    3,242   17,747  65,993
# 2             3  Grand Crossing     75,235    1,123    1,472  71,010
# 3             4   South Chicago    123,575   35,381    9,925  76,399
# 4             5         Calumet     74,396    2,524      843  70,064
# 5             6         Gresham     90,841      914      312  88,525
# 6             7       Englewood     71,071    1,167      262  68,787
# 7             8    Chicago Lawn    247,373  139,854   51,491  52,219
# 8             9         Deering    165,201   94,610   24,307  19,044
# 9            10           Ogden    118,093   73,441    4,300  39,440
# 10           11        Harrison     70,474    8,118    1,664  59,671
# 11           12       Near West    127,869   42,329   51,775  23,039
# 12           14     Shakespeare    117,738   54,039   49,809   8,027
# ...

# %%
pd.read_csv("data/older_data/cleaned_data/complaints-victims_2000-2016_2016-11.csv.gz", compression = "gzip")
# Out:
#           cr_id  gender   age      race
# 0       1000009  FEMALE  37.0  HISPANIC
# 1       1000015  FEMALE  35.0     BLACK
# 2       1000015  FEMALE  24.0     BLACK
# 3       1000020    MALE  27.0     BLACK
# 4       1000021    MALE  26.0     BLACK
# ...         ...     ...   ...       ...
# 20218   1082661    MALE  57.0     BLACK
# 20219   1082664    MALE  37.0     BLACK
# 20220   1082695    MALE  47.0     WHITE
# 20221   1082745    MALE  37.0     BLACK
# 20222  10077725  FEMALE  40.0     WHITE
#
# [20223 rows x 4 columns]

# %%
pd.read_csv("data/older_data/cleaned_data/complaints-accused_2000-2016_2016-11.csv.gz", compression = "gzip")
# Out:
#         row_id     cr_id  birth_year  gender      race appointed_date  \
# 0            1    258996      1949.0    MALE     WHITE     1978-02-27
# 1            2    258997      1965.0  FEMALE     BLACK     1990-07-30
# 2            3    258997      1968.0    MALE     WHITE     1999-03-08
# 3            4    258998      1965.0    MALE     WHITE     1991-11-18
# 4            5    259001      1971.0    MALE  HISPANIC     1996-11-04
# ...        ...       ...         ...     ...       ...            ...
# 125576  125577   1082657      1968.0    MALE     BLACK     1997-09-02
# 125577  125578   1082661      1984.0    MALE     WHITE     2007-07-09
# 125578  125579   1082661      1980.0    MALE  HISPANIC     2007-09-24
# 125579  125580   1082695      1976.0    MALE     WHITE     2000-02-28
# 125580  125581  10773250      1966.0    MALE     BLACK     1994-05-31
#
#         current_unit current_rank  current_star  \
# 0               18.0          SGT           NaN
# ...
