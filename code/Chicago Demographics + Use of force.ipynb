# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
districts = pd.read_csv("chicago-police-data/data/context_data/district_demographics/Districts.csv")
districts
# Out:
#     District_No   District_Name Population   Latino    White   Black  \
# 0             1         Central     62,781    3,766   32,952  13,452
# 1             2       Wentworth     95,439    3,242   17,747  65,993
# 2             3  Grand Crossing     75,235    1,123    1,472  71,010
# 3             4   South Chicago    123,575   35,381    9,925  76,399
# 4             5         Calumet     74,396    2,524      843  70,064
# 5             6         Gresham     90,841      914      312  88,525
# 6             7       Englewood     71,071    1,167      262  68,787
# 7             8    Chicago Lawn    247,373  139,854   51,491  52,219
# 8             9         Deering    165,201   94,610   24,307  19,044
# 9            10           Ogden    118,093   73,441    4,300  39,440
# 10           11        Harrison     70,474    8,118    1,664  59,671
# 11           12       Near West    127,869   42,329   51,775  23,039
# 12           14     Shakespeare    117,738   54,039   49,809   8,027
# 13           15          Austin     59,458    2,265      959  55,468
# 14           16  Jefferson Park    199,482   45,438  138,045   2,022
# 15           17     Albany Park    144,096   62,232   55,743   4,782
# 16           18      Near North    117,041    5,806   88,418  10,681
# 17           19       Town Hall    200,786   20,025  150,551  13,305
# 18           20         Lincoln     91,279   16,519   49,420   9,909
# 19           22     Morgan Park    101,941    3,318   34,863  62,094
# 20           24     Rogers Park    141,038   29,746   60,488  25,322
# 21           25   Grand Central    200,391  133,005   29,371  33,033
#
#     Native_American   Asian  Other Latino% White% Black% Native_American%  \
# 0                95  10,790  1,726      6%    52%    21%               0%
# 1               138   5,837  2,482      3%    19%    69%               0%
# 2               169     312  1,149      1%     2%    94%               0%
# 3               223     258  1,389     29%     8%    62%               0%
# 4               118      38    809      3%     1%    94%               0%
# 5               164      61    865      1%     0%    97%               0%
# 6               136      56    663      2%     0%    97%               0%
# 7               247   2,001  1,561     57%    21%    21%               0%
# 8               173  25,894  1,173     57%    15%    12%               0%
# 9               144     239    529     62%     4%    33%               0%
# 10               73     329    619     12%     2%    85%               0%
# 11              185   8,148  2,393     33%    40%    18%               0%
# 12              189   3,604  2,070     46%    42%     7%               0%
# 13              107     174    485      4%     2%    93%               0%
# 14              299  10,711  2,967     23%    69%     1%               0%
# 15              321  17,373  3,645     43%    39%     3%               0%
# 16              108   9,775  2,253      5%    76%     9%               0%
# 17              308  12,277  4,320     10%    75%     7%               0%
# 18              223  12,792  2,416     18%    54%    11%               0%
# 19              112     352  1,202      3%    34%    61%               0%
# 20              351  20,796  4,335     21%    43%    18%               0%
# 21              214   3,086  1,682     66%    15%    16%               0%
#
#    Asian% Other% Majority
# 0     17%     3%    White
# 1      6%     3%    Black
# 2      0%     2%    Black
# 3      0%     1%    Black
# 4      0%     1%    Black
# 5      0%     1%    Black
# 6      0%     1%    Black
# 7      1%     1%   Latino
# 8     16%     1%   Latino
# 9      0%     0%   Latino
# 10     0%     1%    Black
# 11     6%     2%    Mixed
# 12     3%     2%    Mixed
# 13     0%     1%    Black
# 14     5%     1%    White
# 15    12%     3%    Mixed
# 16     8%     2%    White
# 17     6%     2%    White
# 18    14%     3%    White
# 19     0%     1%    Black
# 20    15%     3%    Mixed
# 21     2%     1%   Latino

# %%
compiled_officer_df = pd.read_csv("chicago-police-data/data/unified_data/profiles/officer-profiles.csv")
compiled_officer_df = compiled_officer_df[["race", "gender"]]
compiled_officer_df.dropna(subset = ["race"], inplace = True)
races = compiled_officer_df["race"].unique()
races
# Out:
# array(['WHITE', 'BLACK', 'HISPANIC', 'ASIAN/PACIFIC ISLANDER',
#        'NATIVE AMERICAN/ALASKAN NATIVE'], dtype=object)

# %%
race_count = [len(compiled_officer_df.loc[compiled_officer_df["race"] == i]) for i in races]
race_count_prop = [(i/sum(race_count)) * 100 for i in race_count]
chicago_tot_pop = sum(districts["Population"])
chicago_white_pop = sum(districts["White"])
chicago_black_pop = sum(districts["Black"])
chicago_latino_pop = sum(districts["Latino"])
chicago_asian_pop = sum(districts["Asian"])
chicago_other_pop = sum(districts["Native American"]) + sum(districts["Other"])
chicago_pop = [chicago_white_pop, chicago_black_pop, chicago_latino_pop, chicago_asian_pop, chicago_other_pop]
chicago_pop_prop = [i/chicago_tot_pop for i in chicago_pop]
chicago_labels = ("White", "Black", "Latino", "Asian", "Other")
sizes_chicago = chicago_pop_prop
explode = (0, 0, 0, 0.1, 0.2)
fig1, ax1 = plt.subplots()
ax1.pie(sizes_chicago, explode = explode, labels = labels, autopct='%1.1f%%', shadow=True, startangle=300, radius = 2)
plt.title("Population Demographics in City of Chicago", bbox={'facecolor':'0.8', 'pad':5})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-537c73bef235> in <module>
#       1 race_count = [len(compiled_officer_df.loc[compiled_officer_df["race"] == i]) for i in races]
#       2 race_count_prop = [(i/sum(race_count)) * 100 for i in race_count]
# ----> 3 chicago_tot_pop = sum(districts["Population"])
#       4 chicago_white_pop = sum(districts["White"])
#       5 chicago_black_pop = sum(districts["Black"])
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
list(districts["Population"])
# Out:
# ['62,781',
#  '95,439',
#  '75,235',
#  '123,575',
#  '74,396',
#  '90,841',
#  '71,071',
#  '247,373',
#  '165,201',
#  '118,093',
#  '70,474',
#  '127,869',
#  '117,738',
#  '59,458',
#  '199,482',
#  '144,096',
#  '117,041',
#  '200,786',
#  '91,279',
#  '101,941',
#  '141,038',
#  '200,391']

# %%
labels = ("No Action or Reprimand", "Suspension/Reprimand/Termination")
sizes = [no_act_prop, suspensions_prop]
explode = (0.75, 0)
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, colors = ['orange', 'red'], autopct='%1.1f%%', shadow=True, startangle=300, radius = 2)
plt.title("Outcomes of Complaints of Excessive Force", bbox={'facecolor':'0.8', 'pad':5})
plt.show()

# %%
officer_df = pd.read_csv("complaints_and_years_served_merged.csv")
officer_df
# Out:
#        Unnamed: 0     UID    cr_id final_finding first_name last_name  \
# 0               0  100527  1005434            UN    ALFONZA  WYSINGER
# 1               1  100527  1005434            UN    ALFONZA  WYSINGER
# 2               2  111051  1005434            UN     JACKIE  CAMPBELL
# 3               3  111051  1005434            UN     JACKIE  CAMPBELL
# 4               4  102914  1031317            NS     CALVIN   GOUSMAN
# ...           ...     ...      ...           ...        ...       ...
# 15379       15379  114956  1080062           NAF   JONATHAN    ROGERS
# 15380       15380  114956  1080062           NAF   JONATHAN    ROGERS
# 15381       15381  104713  1080340           NAF     DALLAS  ARAMBURU
# 15382       15382  104873  1081013           NaN     DANIEL   DUFRENE
# 15383       15383  104873  1081013           NaN     DANIEL   DUFRENE
#
#       middle_initial      race  gender  years_served victim_gender victim_race
# 0                NaN     BLACK    MALE         29.25          MALE       WHITE
# 1                NaN     BLACK    MALE         29.25          MALE       WHITE
# 2                NaN     BLACK  FEMALE         26.09          MALE       WHITE
# 3                NaN     BLACK  FEMALE         26.09          MALE       WHITE
# 4                  A     BLACK    MALE         27.71          MALE       WHITE
# ...              ...       ...     ...           ...           ...         ...
# 15379              L     WHITE    MALE          3.43          MALE       BLACK
# 15380              L     WHITE    MALE          3.43          MALE       BLACK
# 15381              P  HISPANIC  FEMALE          3.40        FEMALE       BLACK
# 15382                    BLACK    MALE          0.41        FEMALE       WHITE
# 15383                    BLACK    MALE          0.41        FEMALE       WHITE
#
# [15384 rows x 12 columns]

# %%
force_df = pd.read_csv("chicago-police-data/data/unified_data/complaints/complaints-accused.csv")
force_df
# Out:
#              UID                                 complaint_category  \
# 0       130469.0  SUPERVISOR RESPONSIBILITY:  FAIL TO OBTAIN COM...
# 1       103495.0         EXCESSIVE FORCE:  ARRESTEE - DURING ARREST
# 2       111845.0         EXCESSIVE FORCE:  ARRESTEE - DURING ARREST
# 3       126148.0         EXCESSIVE FORCE:  ARRESTEE - DURING ARREST
# 4       127906.0         EXCESSIVE FORCE:  ARRESTEE - DURING ARREST
# ...          ...                                                ...
# 244431  117294.0                 EXCESSIVE FORCE / ON DUTY - INJURY
# 244432  107250.0                 EXCESSIVE FORCE / ON DUTY - INJURY
# 244433  111277.0                 EXCESSIVE FORCE / ON DUTY - INJURY
# 244434  128170.0                 EXCESSIVE FORCE / ON DUTY - INJURY
# 244435  130065.0                 EXCESSIVE FORCE / ON DUTY - INJURY
#
#        complaint_code    cr_id  cv final_finding    final_outcome  \
# 0                 12D  C170981   1            NS  NO ACTION TAKEN
# 1                 05A  C170981   1            NS  NO ACTION TAKEN
# 2                 05A  C170981   1            NS  NO ACTION TAKEN
# 3                 05A  C170981   1            NS  NO ACTION TAKEN
# 4                 05A  C170981   1            NS  NO ACTION TAKEN
# ...               ...      ...  ..           ...              ...
# 244431            05A  1080732   3            NS              NaN
# 244432            05A  1080819   3           NaN              NaN
# 244433            05A  1080819   3           NaN              NaN
# 244434            05A  1082535   3            UN              NaN
# 244435            05A  1082535   3            UN              NaN
#
#        recc_finding recc_outcome  link_UID
# 0               NaN          NaN   20040.0
# 1               NaN          NaN    7727.0
# 2               NaN          NaN   17149.0
# 3               NaN          NaN     271.0
# 4               NaN          NaN   11004.0
# ...             ...          ...       ...
# 244431          NaN          NaN   29814.0
# 244432          NaN          NaN    2909.0
# 244433          NaN          NaN    3045.0
# 244434          NaN          NaN    4550.0
# 244435          NaN          NaN   26387.0
#
# [244436 rows x 10 columns]

# %%
df = pd.read_csv("chicago-police-data/data/unified_data/complaints/complaints-victims.csv")
df
# Out:
#          age  birth_year    cr_id  cv  gender      race
# 0       24.0         NaN  1000551   2    MALE     BLACK
# 1       51.0         NaN  1000861   2  FEMALE     BLACK
# 2        NaN         NaN  1001509   2    MALE     WHITE
# 3        NaN         NaN  1001880   2  FEMALE     BLACK
# 4        NaN         NaN  1003246   2    MALE  HISPANIC
# ...      ...         ...      ...  ..     ...       ...
# 124516   NaN      1970.0  1088157   3    MALE     BLACK
# 124517   NaN      1989.0  1087109   3  FEMALE     BLACK
# 124518   NaN      1958.0  1084557   3    MALE     BLACK
# 124519   NaN         NaN  1088434   3  FEMALE     BLACK
# 124520   NaN         NaN  1088444   3    MALE     WHITE
#
# [124521 rows x 6 columns]

# %%
force_df.loc[force_df["cr_id"].isin(df["cr_id"])]
# Out:
#              UID                  complaint_category complaint_code    cr_id  \
# 150900  120840.0                      ILLEGAL ARREST            03D  1000258
# 150901  101162.0                      ILLEGAL ARREST            03D  1000258
# 150902  105539.0                      ILLEGAL ARREST            03D  1000258
# 150903  108963.0                      ILLEGAL ARREST            03D  1000258
# 150904  105464.0                      ILLEGAL ARREST            03D  1000258
# ...          ...                                 ...            ...      ...
# 244431  117294.0  EXCESSIVE FORCE / ON DUTY - INJURY            05A  1080732
# 244432  107250.0  EXCESSIVE FORCE / ON DUTY - INJURY            05A  1080819
# 244433  111277.0  EXCESSIVE FORCE / ON DUTY - INJURY            05A  1080819
# 244434  128170.0  EXCESSIVE FORCE / ON DUTY - INJURY            05A  1082535
# 244435  130065.0  EXCESSIVE FORCE / ON DUTY - INJURY            05A  1082535
#
#         cv final_finding    final_outcome recc_finding     recc_outcome  \
# 150900   2            UN  No Action Taken           UN  No Action Taken
# 150901   2            UN  No Action Taken           UN  No Action Taken
# 150902   2            UN  No Action Taken           UN  No Action Taken
# 150903   2            UN  No Action Taken           UN  No Action Taken
# 150904   2            UN  No Action Taken           UN  No Action Taken
# ...     ..           ...              ...          ...              ...
# 244431   3            NS              NaN          NaN              NaN
# 244432   3           NaN              NaN          NaN              NaN
# 244433   3           NaN              NaN          NaN              NaN
# 244434   3            UN              NaN          NaN              NaN
# 244435   3            UN              NaN          NaN              NaN
#
#         link_UID
# 150900   22414.0
# 150901    9389.0
# 150902    7423.0
# 150903   22074.0
# 150904    2144.0
# ...          ...
# 244431   29814.0
# 244432    2909.0
# 244433    3045.0
# 244434    4550.0
# 244435   26387.0
#
# [60281 rows x 10 columns]

# %%
inner_join = pd.merge(force_df, df, how = "outer", on = ["cr_id"])[["UID", "complaint_category", "complaint_code", "cr_id", "final_finding", "final_outcome", "link_UID", "gender", "race"] ]
inner_join
# Out:
#              UID                                 complaint_category  \
# 0       130469.0  SUPERVISOR RESPONSIBILITY:  FAIL TO OBTAIN COM...
# 1       103495.0         EXCESSIVE FORCE:  ARRESTEE - DURING ARREST
# 2       111845.0         EXCESSIVE FORCE:  ARRESTEE - DURING ARREST
# 3       126148.0         EXCESSIVE FORCE:  ARRESTEE - DURING ARREST
# 4       127906.0         EXCESSIVE FORCE:  ARRESTEE - DURING ARREST
# ...          ...                                                ...
# 371182       NaN                                                NaN
# 371183       NaN                                                NaN
# 371184       NaN                                                NaN
# 371185       NaN                                                NaN
# 371186       NaN                                                NaN
#
#        complaint_code    cr_id final_finding    final_outcome  link_UID  \
# 0                 12D  C170981            NS  NO ACTION TAKEN   20040.0
# 1                 05A  C170981            NS  NO ACTION TAKEN    7727.0
# 2                 05A  C170981            NS  NO ACTION TAKEN   17149.0
# 3                 05A  C170981            NS  NO ACTION TAKEN     271.0
# 4                 05A  C170981            NS  NO ACTION TAKEN   11004.0
# ...               ...      ...           ...              ...       ...
# 371182            NaN  1088167           NaN              NaN       NaN
# 371183            NaN  1088170           NaN              NaN       NaN
# 371184            NaN  1088166           NaN              NaN       NaN
# 371185            NaN  1088165           NaN              NaN       NaN
# 371186            NaN  1088444           NaN              NaN       NaN
#
#         gender   race
# 0          NaN    NaN
# 1          NaN    NaN
# 2          NaN    NaN
# 3          NaN    NaN
# 4          NaN    NaN
# ...        ...    ...
# 371182    MALE  WHITE
# 371183    MALE  BLACK
# 371184    MALE  BLACK
# 371185  FEMALE  BLACK
# 371186    MALE  WHITE
#
# [371187 rows x 9 columns]

# %%
excess_force = inner_join.loc[inner_join["complaint_code"] == "05A"].dropna(subset = ["final_finding"])
excess_force
# Out:
#              UID                          complaint_category complaint_code  \
# 1       103495.0  EXCESSIVE FORCE:  ARRESTEE - DURING ARREST            05A
# 2       111845.0  EXCESSIVE FORCE:  ARRESTEE - DURING ARREST            05A
# 3       126148.0  EXCESSIVE FORCE:  ARRESTEE - DURING ARREST            05A
# 4       127906.0  EXCESSIVE FORCE:  ARRESTEE - DURING ARREST            05A
# 227     113753.0  EXCESSIVE FORCE:  ARRESTEE - DURING ARREST            05A
# ...          ...                                         ...            ...
# 300431  117294.0          EXCESSIVE FORCE / ON DUTY - INJURY            05A
# 300434  128170.0          EXCESSIVE FORCE / ON DUTY - INJURY            05A
# 300435  128170.0          EXCESSIVE FORCE / ON DUTY - INJURY            05A
# 300436  130065.0          EXCESSIVE FORCE / ON DUTY - INJURY            05A
# 300437  130065.0          EXCESSIVE FORCE / ON DUTY - INJURY            05A
#
#           cr_id final_finding    final_outcome  link_UID  gender   race
# 1       C170981            NS  NO ACTION TAKEN    7727.0     NaN    NaN
# 2       C170981            NS  NO ACTION TAKEN   17149.0     NaN    NaN
# 3       C170981            NS  NO ACTION TAKEN     271.0     NaN    NaN
# 4       C170981            NS  NO ACTION TAKEN   11004.0     NaN    NaN
# 227     C221987            NS  NO ACTION TAKEN    9102.0     NaN    NaN
# ...         ...           ...              ...       ...     ...    ...
# 300431  1080732            NS              NaN   29814.0    MALE  BLACK
# 300434  1082535            UN              NaN    4550.0  FEMALE  WHITE
# 300435  1082535            UN              NaN    4550.0  FEMALE  WHITE
# 300436  1082535            UN              NaN   26387.0  FEMALE  WHITE
# 300437  1082535            UN              NaN   26387.0  FEMALE  WHITE
#
# [42006 rows x 9 columns]

# %%
excess_force["final_outcome"].unique()
# Out:
# array(['NO ACTION TAKEN', 'REINSTATED POLICE BD', '30 DAY SUSPENSION',
#        'RESIGNED -NOT SERVED', '5 DAY SUSPENSION', '2 DAY SUSPENSION',
#        'SUSPENDED OVR 30 DAY', 'SEPARATION', '1 DAY SUSPENSION',
#        'REPRIMAND', '3 DAY SUSPENSION', '20 DAY SUSPENSION',
#        '10 DAY SUSPENSION', '15 DAY SUSPENSION', '**PENALTY NOT SERVED',
#        '6 DAY SUSPENSION', 'SUSTAINED-NO PENALTY', '4 DAY SUSPENSION',
#        '7 DAY SUSPENSION', 'REINSTATED COURT ACT', 'ADMIN. TERMINATION',
#        '8 DAY SUSPENSION', 'No Action Taken', '1 Day Suspension',
#        'Reprimand', '5 Day Suspension', 'Unknown', '3 Day Suspension',
#        'Penalty Not Served', '10 Day Suspension', '2 Day Suspension',
#        'Separation', '15 Day Suspension', 'Suspended over 30 Days',
#        '4 Day Suspension', '20 Day Suspension', '8 Day Suspension',
#        'Resigned', '999', '7 Day Suspension', 'Violation Noted',
#        '45 Day Suspension', '30 Day Suspension',
#        'Reinstated by Court Action', 'Reinstated by Police Board',
#        '25 Day Suspension', '11 Day Suspension', '90 Day Suspension',
#        '21 Day Suspension', nan, '60 Day Suspension', '31 Day Suspension'],
#       dtype=object)

# %%
excess_force.dropna(subset = ["final_outcome"], inplace = True)
no_act = ["NO ACTION TAKEN", "No Action Taken"]

suspensions = [i for i in excess_force["final_outcome"].unique() if i not in no_act]
total_excess = len(excess_force)
no_act_prop = (len(excess_force.loc[excess_force["final_outcome"].isin(no_act)])/total_excess) * 100
suspensions_prop = (len(excess_force.loc[excess_force["final_outcome"].isin(suspensions)])/total_excess) * 100
labels = ("No Action or Reprimand", "Suspension/Reprimand/Termination")
sizes = [no_act_prop, suspensions_prop]
explode = (0.75, 0)
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, colors = ['orange', 'red'], autopct='%1.1f%%', shadow=True, startangle=300, radius = 2)
plt.title("Outcomes of Complaints of Excessive Force", bbox={'facecolor':'0.8', 'pad':5})
plt.show()

#MAKE PLOT LESS UGLY
